# %%
import Notebooks.scripts.utility as util
import Notebooks.scripts.graph_builder as gb

# %% [markdown]
# This notebook is the final product for the TDI Capstone project called: "How to build a better desktop"

# %% [markdown]
# To run the model you need to select a component type (CPU or GPU) and select a component model (e.g. Core i9-10920XE).
# A full list of available components is available.

# %%
component_type = 'GPU' #CPU or GPU

# %% [markdown]
# For a list of possible components execute the following cell.

# %%
component_dataframe = util.get_component_dataframe(component_type)

# %%
component_dataframe.loc[component_dataframe.brand == "AMD"].iloc[-50:]
# Out:
#                                    Release Date brand
# name
# Radeon 610 Mobile                    2019-05-23   AMD
# Radeon 620 Mobile                    2019-05-13   AMD
# Radeon 625 Mobile                    2019-05-13   AMD
# Radeon 630 Mobile                    2019-05-13   AMD
# Radeon Picasso                       2019-02-12   AMD
# Radeon Picasso Embedded              2019-02-12   AMD
# Radeon Picasso Embedded              2019-02-12   AMD
# Radeon Pro 5300M                     2019-11-13   AMD
# Radeon Pro 5500M                     2019-11-13   AMD
# Radeon Pro 570X                      2019-03-18   AMD
# Radeon Pro 575X                      2019-03-18   AMD
# Radeon Pro 580X                      2019-03-18   AMD
# Radeon Pro Vega 48                   2019-03-19   AMD
# Radeon Pro Vega 64X                  2019-03-19   AMD
# Radeon Pro W5300M                    2019-11-13   AMD
# Radeon Pro W5500M                    2019-11-13   AMD
# ...

# %% [markdown]
# Once you have decided on a component you can compare it to forecasted future requirements.
#
# The forecast uses historical hardware releases and game requirements for the forecast. The selected component is overlaid on the forecast.

# %%
component_for_comparison = 'Radeon Pro 5500M'

# %%
gb.make_graph(component_type, component_for_comparison)
