# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup as soup
import urllib.request
import time
import string as st
import pandas as pd
import json
import os

# %%
def simple_get(url):
    """
    return a url if good and log the error otherwise
    """
    try:
        with closing(get(url)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                print(resp.content)
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None

def adaptive_get(url,t):
    "times get requests as to not trip rate limits, returns soup of page or None"
    time.sleep(t)
    html_text = simple_get(url)
    
    if html_text == None:
        html_text = try_again(url) #try again returns html text
        t += 10
    
    'if try_again fails to get the link then return none'
    if html_text == None:
        notify(f"URL not captured:{url}")
        return None
    else:
        return (soup(html_text),t)
    
def try_again(url):
    "waits for a longer period of time so download limit can reset"
    notify(f"Rate limit hit. Taking break")
    time.sleep(2500)
    
    html_text = simple_get(url)
    if html_text == None:
        notify(f"Rate limit hit AGAIN :( : Pausing for longer")
        time.sleep(5000)
        html_text = simple_get(url)
    
    return html_text

def notify(string):
    "prints notifications to a file containing progress and the screen"
    print(string)
    with open("progress.txt", 'a') as f:
        f.write(string+"\n")
        
def is_good_response(resp):
    """
    returns true if response is good and html is found
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)

def log_error(e):
    """
    print the error
    """
    notify(e)

# %%
def find_processors():
    "This is the code to pull the cpu names and the link to each cpu."
    brands = ['Intel','AMD','ATI','Matrox','NVIDIA','XGI']
    years = [1986,1987,1988,1990,1992,1993]+list(range(1995,2021))
    mobiles = ["Yes","No"]
    base = "https://www.techpowerup.com"
    t=75
    gpu_list = []
    for brand in brands:
        for year in years:
            for mobile in mobiles:
                notify(f"Starting {brand} {year}")
                url = f"https://www.techpowerup.com/gpu-specs/?mfgr={brand}&released={year}&mobile={mobile}&sort=name"
                page_soup,t = adaptive_get(url,t)
                relevant_lines = page_soup.select("table.processors a")
                if len(relevant_lines) > 0:
                    for line in relevant_lines:
                        gpu_name = line.string
                        gpu_link = "".join([base,line['href']])
                        gpu_list.append({'name': gpu_name,"brand":brand, 'link':gpu_link})
    return gpu_list

# %%
def gpu_details(processor_list):
    detail_list = []
    sleep_time=75
    for i, entry in enumerate(processor_list):
        new_entry = entry.copy()
        if i%5 == 0:
            notify(f"{i/len(processor_list)*100:.1f}% Complete")
            
        link = entry['link']

        "get html from link"
        card_soup, sleep_time = adaptive_get(link, sleep_time)
        
        "add available information from website to processor database"
        keys = [x.text.strip() for x in card_soup.select('div.sectioncontainer div dt')]
        values = [x.text.strip() for x in card_soup.select('div.sectioncontainer div dd')]

        detail_list.append(dict(zip(keys,values)))
        
        with open('ongoing_gpu_collected_data.json', 'a') as f:
            json.dump(detail_list[-1], f)
        
    return detail_list

# %%
"get all processor links"
gpu_links = find_processors()
with open('gpu_urls.json', 'w') as f:
    json.dump(gpu_links,f)
# Out:
# Starting Intel 1986
# Starting Intel 1986
# Starting Intel 1987
# Starting Intel 1987
# Starting Intel 1988
# Starting Intel 1988
# Starting Intel 1990
# Starting Intel 1990
# Starting Intel 1992
# Starting Intel 1993
# Starting Intel 1993
# Starting Intel 1995
# Starting Intel 1995
# Starting Intel 1996
# Starting Intel 1996
# Starting Intel 1997
# Starting Intel 1997
# Starting Intel 1998
# Starting Intel 1998
# Starting Intel 1999
# Starting Intel 1999
# Starting Intel 2000
# Starting Intel 2000
# Starting Intel 2001
# Starting Intel 2001
# Starting ATI 2010
# Starting ATI 2011
# Starting ATI 2011
# Starting ATI 2012
# Starting ATI 2012
# Starting ATI 2013
# Starting ATI 2013
# Starting ATI 2014
# Starting ATI 2014
# Starting ATI 2015
# Starting ATI 2015
# Starting ATI 2016
# Starting ATI 2016
# Starting ATI 2017
# Starting ATI 2017
# Starting ATI 2018
# Starting ATI 2018
# Starting ATI 2019
# Starting ATI 2019
# Starting ATI 2020
# Starting ATI 2020
# Starting Matrox 1986
# Starting Matrox 1986
# Starting Matrox 1987
# Starting Matrox 1987
# Starting Matrox 1988
# Starting Matrox 1988
# Starting Matrox 1990
# Starting Matrox 1990
# Starting Matrox 1992
# Starting Matrox 1992
# Starting Matrox 1993
# Starting Matrox 1993
# Starting Matrox 1995
# Starting Matrox 1995
# Starting Matrox 1996
# Starting Matrox 1996
# Starting Matrox 1997
# Starting Matrox 1997
# Starting Matrox 1998
# Starting Matrox 1998
# Starting Matrox 1999
# Starting Matrox 1999
# Starting Matrox 2000
# Starting Matrox 2000
# Starting Matrox 2001
# Starting Matrox 2001
# Starting Matrox 2002
# Starting Matrox 2002
# Starting Matrox 2003
# Starting Matrox 2003
# Starting Matrox 2004
# Starting Matrox 2004
# Starting Matrox 2005
# Starting Matrox 2005
# Starting Matrox 2006
# Starting Matrox 2006
# Starting Matrox 2007
# Starting Matrox 2007
# Starting Matrox 2008
# Starting Matrox 2008
# Starting Matrox 2009
# Starting Matrox 2009
# Starting Matrox 2010
# Starting Matrox 2010
# Starting Matrox 2011
# Starting Matrox 2011
# Starting Matrox 2012
# Starting Matrox 2012
# Starting Matrox 2013
# Starting Matrox 2013
# Starting Matrox 2014
# Starting Matrox 2014
# Starting Matrox 2015
# Starting Matrox 2015
# Starting Matrox 2016
# Starting Matrox 2016
# Starting Matrox 2017
# Starting Matrox 2017
# Starting Matrox 2018
# Starting Matrox 2018
# Starting Matrox 2019
# Starting Matrox 2019
# Starting Matrox 2020
# Starting Matrox 2020
# Starting NVIDIA 1986
# Starting NVIDIA 1986
# Starting NVIDIA 1987
# Starting NVIDIA 1987
# Starting NVIDIA 1988
# Starting NVIDIA 1988
# Starting NVIDIA 1990
# Starting NVIDIA 1990
# Starting NVIDIA 1992
# Starting NVIDIA 1992
# Starting NVIDIA 1993
# Starting NVIDIA 1993
# Starting NVIDIA 1995
# Starting NVIDIA 1995
# Starting NVIDIA 1996
# Starting NVIDIA 1996
# Starting NVIDIA 1997
# Starting NVIDIA 1997
# Starting NVIDIA 1998
# Starting NVIDIA 1998
# Starting NVIDIA 1999
# Starting NVIDIA 1999
# Starting NVIDIA 2000
# Starting NVIDIA 2000
# Starting NVIDIA 2001
# Starting NVIDIA 2001
# Starting NVIDIA 2002
# Starting NVIDIA 2002
# Starting NVIDIA 2003
# Starting NVIDIA 2003
# Starting NVIDIA 2004
# Starting NVIDIA 2004
# Starting NVIDIA 2005
# Starting NVIDIA 2005
# Starting NVIDIA 2006
# Starting NVIDIA 2006
# Starting NVIDIA 2007
# Starting NVIDIA 2007
# Starting NVIDIA 2008
# Starting NVIDIA 2008
# Starting NVIDIA 2009
# Starting NVIDIA 2009
# Starting NVIDIA 2010
# Starting NVIDIA 2010
# Starting NVIDIA 2011
# Starting NVIDIA 2011
# Starting NVIDIA 2012
# Starting NVIDIA 2012
# Starting NVIDIA 2013
# Starting NVIDIA 2013
# Starting NVIDIA 2014
# Starting NVIDIA 2014
# Starting NVIDIA 2015
# Starting NVIDIA 2015
# Starting NVIDIA 2016
# Starting NVIDIA 2016
# Starting NVIDIA 2017
# Starting NVIDIA 2017
# Starting NVIDIA 2018
# Starting NVIDIA 2018
# Starting NVIDIA 2019
# Starting NVIDIA 2019
# Starting NVIDIA 2020
# Starting NVIDIA 2020
# Starting XGI 1986
# Starting XGI 1986
# Starting XGI 1987
# Starting XGI 1987
# Starting XGI 1988
# Starting XGI 1988
# Starting XGI 1990
# Starting XGI 1990
# Starting XGI 1992
# Starting XGI 1992
# Starting XGI 1993
# Starting XGI 1993
# Starting XGI 1995
# Starting XGI 1995
# Starting XGI 1996
# Starting XGI 1996
# Starting XGI 1998
# Starting XGI 1998
# Starting XGI 1999
# Starting XGI 1999
# Starting XGI 2000
# Starting XGI 2000
# Starting XGI 2001
# Starting XGI 2001
# Starting XGI 2002
# Starting XGI 2002
# Starting XGI 2003
# Starting XGI 2003
# Starting XGI 2004
# Starting XGI 2004
# Starting XGI 2005
# Starting XGI 2005
# Starting XGI 2006
# Starting XGI 2006
# Starting XGI 2007
# Starting XGI 2007
# Starting XGI 2008
# Starting XGI 2008
# Starting XGI 2009
# Starting XGI 2009
# Starting XGI 2010
# Starting XGI 2010
# Starting XGI 2011
# Starting XGI 2011
# Starting XGI 2012
# Starting XGI 2012
# Starting XGI 2013
# Starting XGI 2013
# Starting XGI 2014
# Starting XGI 2014
# Starting XGI 2015
# Starting XGI 2015
# Starting XGI 2016
# Starting XGI 2016
# Starting XGI 2017
# Starting XGI 2017
# Starting XGI 2018
# Starting XGI 2018
# Starting XGI 2019
# Starting XGI 2019
# Starting XGI 2020
# Starting XGI 2020

# %%
gpu_list[0]['link']
# Out:
# 'https://www.techpowerup.com/gpu-specs/i740.c1288'

# %%
'get links to individual cpus'
if 'gpu_list' not in locals():
    with open('gpu_urls.json', 'r') as f:
        gpu_list = json.load(f)
        
'fill in details on gpus in list using the output of find_processors'
full_details_list = gpu_details(gpu_list)

with open('final_gpu_list.json', 'w') as f:
    json.dump(full_details_list, f)
# Out:
# 0.0% Complete
# 0.1% Complete
# 0.2% Complete
# 0.3% Complete
# 0.4% Complete
# 0.5% Complete
# 0.6% Complete
# 0.7% Complete
# 0.8% Complete
# 0.9% Complete
# 1.0% Complete
# 1.1% Complete
# 1.2% Complete
# 1.2% Complete
# 1.3% Complete
# 1.4% Complete
# 1.5% Complete
# 1.6% Complete
# 1.7% Complete
# 1.8% Complete
# 1.9% Complete
# 2.0% Complete
# 2.1% Complete
# 2.2% Complete
# 2.3% Complete
# 2.4% Complete
# 2.5% Complete
# 2.6% Complete
# 2.7% Complete
# 2.8% Complete
# 2.9% Complete
# 3.0% Complete
# 3.1% Complete
# 3.2% Complete
# 3.3% Complete
# 3.4% Complete
# 3.5% Complete
# 3.5% Complete
# 3.6% Complete
# 3.7% Complete
# 95.7% Complete
# 95.8% Complete
# 95.9% Complete
# 96.0% Complete
# 96.1% Complete
# 96.1% Complete
# 96.2% Complete
# 96.3% Complete
# 96.4% Complete
# 96.5% Complete
# 96.6% Complete
# 96.7% Complete
# 96.8% Complete
# 96.9% Complete
# 97.0% Complete
# 97.1% Complete
# 97.2% Complete
# 97.3% Complete
# 97.4% Complete
# 97.5% Complete
# 97.6% Complete
# 97.7% Complete
# 97.8% Complete
# 97.9% Complete
# 98.0% Complete
# 98.1% Complete
# 98.2% Complete
# 98.3% Complete
# 98.4% Complete
# 98.4% Complete
# 98.5% Complete
# 98.6% Complete
# 98.7% Complete
# 98.8% Complete
# 98.9% Complete
# 99.0% Complete
# 99.1% Complete
# 99.2% Complete
# 99.3% Complete
# 99.4% Complete
# 99.5% Complete
# 99.6% Complete
# 99.7% Complete
# 99.8% Complete
# 99.9% Complete
# 100.0% Complete

# %%
resp = simple_get('https://www.techpowerup.com/gpu-specs/?mfgr=AMD&released=2015&mobile=No&sort=name')
base = "https://www.techpowerup.com"
test = soup(resp)
relevant_lines = test.select("table.processors a")
if len(relevant_lines) > 0:
    for line in relevant_lines:
        gpu_name = line.string
        gpu_link = "".join([base,line['href']])
        print(gpu_link)
        break
# Out:
# https://www.techpowerup.com/gpu-specs/firepro-s9170.c2744

# %%
test.select("table.processors a")
# Out:
# [<a href="/gpu-specs/firepro-s9170.c2744">FirePro S9170</a>,
#  <a href="/gpu-specs/amd-hawaii.g738">Hawaii</a>,
#  <a href="/gpu-specs/firepro-w4300.c2781">FirePro W4300</a>,
#  <a href="/gpu-specs/amd-bonaire.g568">Bonaire</a>,
#  <a href="/gpu-specs/radeon-r2-graphics.c2498">Radeon R2 Graphics</a>,
#  <a href="/gpu-specs/amd-beema.g750">Beema</a>,
#  <a href="/gpu-specs/radeon-r3-graphics.c2494">Radeon R3 Graphics</a>,
#  <a href="/gpu-specs/amd-beema.g750">Beema</a>,
#  <a href="/gpu-specs/radeon-r5-310-oem.c3025">Radeon R5 310 OEM</a>,
#  <a href="/gpu-specs/amd-caicos.g114">Caicos</a>,
#  <a href="/gpu-specs/radeon-r5-310-oem.c2680">Radeon R5 310 OEM</a>,
#  <a href="/gpu-specs/amd-caicos.g114">Caicos</a>,
#  <a href="/gpu-specs/radeon-r5-330-oem.c2727">Radeon R5 330 OEM</a>,
#  <a href="/gpu-specs/amd-hainan.g817">Hainan</a>,
#  <a href="/gpu-specs/radeon-r5-340-oem.c2683">Radeon R5 340 OEM</a>,
#  <a href="/gpu-specs/amd-oland.g389">Oland</a>,
#  <a href="/gpu-specs/radeon-r5-340x-oem.c2820">Radeon R5 340X OEM</a>,
#  <a href="/gpu-specs/amd-oland.g389">Oland</a>,
#  <a href="/gpu-specs/radeon-r7-340-oem.c2946">Radeon R7 340 OEM</a>,
#  <a href="/gpu-specs/amd-oland.g389">Oland</a>,
#  <a href="/gpu-specs/radeon-r7-340-oem.c2684">Radeon R7 340 OEM</a>,
#  <a href="/gpu-specs/amd-oland.g389">Oland</a>,
#  <a href="/gpu-specs/radeon-r7-350-oem.c2682">Radeon R7 350 OEM</a>,
#  <a href="/gpu-specs/amd-oland.g389">Oland</a>,
#  <a href="/gpu-specs/radeon-r7-350x-oem.c2819">Radeon R7 350X OEM</a>,
#  <a href="/gpu-specs/amd-oland.g389">Oland</a>,
#  <a href="/gpu-specs/radeon-r7-360.c2733">Radeon R7 360</a>,
#  <a href="/gpu-specs/amd-tobago.g777">Tobago</a>,
#  <a href="/gpu-specs/radeon-r7-360-896sp.c2811">Radeon R7 360 896SP</a>,
#  <a href="/gpu-specs/amd-tobago.g777">Tobago</a>,
#  <a href="/gpu-specs/radeon-r7-360e.c2827">Radeon R7 360E</a>,
#  <a href="/gpu-specs/amd-tobago.g777">Tobago</a>,
#  <a href="/gpu-specs/radeon-r7-370.c2645">Radeon R7 370</a>,
#  <a href="/gpu-specs/amd-trinidad.g776">Trinidad</a>,
#  <a href="/gpu-specs/radeon-r9-270-1024sp.c2679">Radeon R9 270 1024SP</a>,
#  <a href="/gpu-specs/amd-pitcairn.g420">Pitcairn</a>,
#  <a href="/gpu-specs/radeon-r9-360-oem.c2661">Radeon R9 360 OEM</a>,
#  <a href="/gpu-specs/amd-tobago.g777">Tobago</a>,
#  <a href="/gpu-specs/radeon-r9-370.c2726">Radeon R9 370</a>,
#  <a href="/gpu-specs/amd-trinidad.g776">Trinidad</a>,
#  <a href="/gpu-specs/radeon-r9-370-1024sp.c2800">Radeon R9 370 1024SP</a>,
#  <a href="/gpu-specs/amd-trinidad.g776">Trinidad</a>,
#  <a href="/gpu-specs/radeon-r9-370x.c2754">Radeon R9 370X</a>,
#  <a href="/gpu-specs/amd-trinidad.g776">Trinidad</a>,
#  <a href="/gpu-specs/radeon-r9-380.c2734">Radeon R9 380</a>,
#  <a href="/gpu-specs/amd-antigua.g780">Antigua</a>,
#  <a href="/gpu-specs/radeon-r9-380-oem.c2725">Radeon R9 380 OEM</a>,
#  <a href="/gpu-specs/amd-antigua.g780">Antigua</a>,
#  <a href="/gpu-specs/radeon-r9-380x.c2758">Radeon R9 380X</a>,
#  <a href="/gpu-specs/amd-antigua.g780">Antigua</a>,
#  <a href="/gpu-specs/radeon-r9-390.c2664">Radeon R9 390</a>,
#  <a href="/gpu-specs/amd-grenada.g779">Grenada</a>,
#  <a href="/gpu-specs/radeon-r9-390-x2.c2755">Radeon R9 390 X2</a>,
#  <a href="/gpu-specs/amd-grenada.g779">Grenada</a>,
#  <a href="/gpu-specs/radeon-r9-390x.c2663">Radeon R9 390X</a>,
#  <a href="/gpu-specs/amd-grenada.g779">Grenada</a>,
#  <a href="/gpu-specs/radeon-r9-fury.c2736">Radeon R9 FURY</a>,
#  <a href="/gpu-specs/amd-fiji.g774">Fiji</a>,
#  <a href="/gpu-specs/radeon-r9-fury-x.c2677">Radeon R9 FURY X</a>,
#  <a href="/gpu-specs/amd-fiji.g774">Fiji</a>,
#  <a href="/gpu-specs/radeon-r9-fury-x2.c2741">Radeon R9 FURY X2</a>,
#  <a href="/gpu-specs/amd-fiji.g774">Fiji</a>,
#  <a href="/gpu-specs/radeon-r9-nano.c2735">Radeon R9 Nano</a>,
#  <a href="/gpu-specs/amd-fiji.g774">Fiji</a>]
