# %%
import pandas as pd
import re
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
code_flops_df = pd.read_csv("../../data/raw_data/codename_to_flops.csv")
raw_list = pd.read_json("../../data/raw_data/final_cpu_list.json")
raw_list = raw_list[raw_list['Market:'] == 'Desktop']

# %%
new_list = raw_list[['name','brand','Released:', 'Generation:','Codename:','Frequency:','# of Cores:']].dropna()

# %%
from dateutil.parser import parse
def cpu_date_parser(df):
    """cleans the gpu dataframe removing entries without dates and converting the date column to date format"""
    df['Released:'] = df[df['Released:'].isin(["Unknown","Never Released"]) == False]['Released:']
    df = df.dropna().copy()
    df['Released:'] = df["Released:"].apply(parse, fuzzy=True)
    return df

def prefixed_number_to_int(cell):
    """used to convert texture rate with letter (100M) to int"""
    val,mod = cell.split()
    mod_val = {"G":1,"M":1/1000}[mod[0]]
    return pd.to_numeric(val)*mod_val

def generation_scrubber(text):
    "removes the newline character and all following charaters from text"
    out = re.search(r"(.*)\n", text)
    return out.groups(0)[0]

# %%
new_list.columns
# Out:
# Index(['name', 'brand', 'Released:', 'Generation:', 'Codename:', 'Frequency:',
#        '# of Cores:'],
#       dtype='object')

# %%
raw_list
# Out:
#                           name  brand  \
# 0                Pentium 4 1.4  Intel
# 1                Pentium 4 1.5  Intel
# 2             Pentium III 1133  Intel
# 3                Pentium 4 1.3  Intel
# 4                Pentium 4 1.4  Intel
# ...                        ...    ...
# 1971             Ryzen 9 3900X    AMD
# 1972             Ryzen 9 3950X    AMD
# 1973  Ryzen Threadripper 3960X    AMD
# 1974  Ryzen Threadripper 3970X    AMD
# 1975  Ryzen Threadripper 3980X    AMD
#
#                                                    link           Socket:  \
# 0     https://www.techpowerup.com/cpudb/296/pentium-...  Intel Socket 423
# 1     https://www.techpowerup.com/cpudb/297/pentium-...  Intel Socket 423
# 2     https://www.techpowerup.com/cpudb/1290/pentium...  Intel Socket 370
# 3     https://www.techpowerup.com/cpudb/1269/pentium...  Intel Socket 478
# 4     https://www.techpowerup.com/cpudb/1244/pentium...  Intel Socket 478
# ...                                                 ...               ...
# 1971  https://www.techpowerup.com/cpudb/2128/ryzen-9...    AMD Socket AM4
# 1972  https://www.techpowerup.com/cpudb/2203/ryzen-9...    AMD Socket AM4
# 1973  https://www.techpowerup.com/cpudb/2268/ryzen-t...    AMD Socket TR4
# 1974  https://www.techpowerup.com/cpudb/2269/ryzen-t...    AMD Socket TR4
# 1975  https://www.techpowerup.com/cpudb/2267/ryzen-t...    AMD Socket TR4
#
#      Foundry: Process Size:    Transistors: Die Size: Package: tCaseMax:  \
# 0       Intel        180 nm      42 million   217 mm²     µPGA      72°C
# 1       Intel        180 nm      42 million   217 mm²     µPGA      73°C
# 2       Intel        180 nm      44 million    80 mm²     µPGA      69°C
# 3       Intel        180 nm      42 million   217 mm²     µPGA      70°C
# 4       Intel        180 nm      42 million   217 mm²     µPGA      72°C
# ...       ...           ...             ...       ...      ...       ...
# 1971     TSMC          7 nm  19,200 million   unknown            unknown
# 1972     TSMC          7 nm  19,200 million   unknown            unknown
# 1973     TSMC          7 nm  19,200 million   unknown    sTRX4   unknown
# 1974     TSMC          7 nm  19,200 million   unknown    sTRX4   unknown
# 1975     TSMC          7 nm  19,200 million   unknown    sTRX4   unknown
#
#      Frequency:   Turbo Clock: Base Clock: Multiplier: Multiplier Unlocked:  \
# 0      1400 MHz            N/A     100 MHz       14.0x                   No
# 1      1500 MHz            N/A     100 MHz       15.0x                   No
# 2      1133 MHz            N/A     133 MHz        8.5x                   No
# 3      1300 MHz            N/A     100 MHz       13.0x                   No
# 4      1400 MHz            N/A     100 MHz       14.0x                   No
# ...         ...            ...         ...         ...                  ...
# 1971    3.8 GHz  up to 4.6 GHz     100 MHz       38.0x                  Yes
# 1972    3.5 GHz  up to 4.7 GHz     100 MHz       35.0x                  Yes
# 1973    3.8 GHz  up to 4.5 GHz     100 MHz       38.0x                  Yes
# 1974    3.7 GHz  up to 4.5 GHz     100 MHz       37.0x                  Yes
# 1975    3.5 GHz  up to 4.7 GHz     100 MHz       35.0x                  Yes
#
#       Voltage:   TDP:  Market: Production Status: Released:   Codename:  \
# 0       1.75 V   55 W  Desktop        End-of-life  Nov 2000  Willamette
# 1       1.75 V   58 W  Desktop        End-of-life  Nov 2000  Willamette
# 2       1.75 V   29 W  Desktop        End-of-life  Jul 2000  Coppermine
# 3       1.75 V   52 W  Desktop        End-of-life  Jan 2001  Willamette
# 4       1.75 V   55 W  Desktop        End-of-life  Aug 2001  Willamette
# ...        ...    ...      ...                ...       ...         ...
# 1971  variable  125 W  Desktop             Active  Jul 2019     Matisse
# 1972  variable  105 W  Desktop             Active  Nov 2019     Matisse
# 1973  variable  280 W  Desktop             Active  Nov 2019     Matisse
# 1974  variable  280 W  Desktop             Active  Nov 2019     Matisse
# 1975  variable  280 W  Desktop             Active  Nov 2019     Matisse
#
#                                 Generation:                          Part#:  \
# 0                   Pentium 4\n(Willamette)            SL4SGSL4SCSL4X2SL4WS
# 1                   Pentium 4\n(Willamette)  SL4TYSL4WTSL4SHSL5TNSL5SXSL4X3
# 2                 Pentium III\n(Coppermine)                      SL5B2SL4YV
# 3                   Pentium 4\n(Willamette)            SL5FWSL4SFSL4QDSL5GC
# 4                   Pentium 4\n(Willamette)            SL5N7SL59USL5UESL5TG
# ...                                     ...                             ...
# 1971            Ryzen 9\n(Zen 2  (Matisse))                         unknown
# 1972            Ryzen 9\n(Zen 2  (Matisse))                         unknown
# 1973  Ryzen Threadripper\n(Zen 2 (Matisse))                         unknown
# 1974  Ryzen Threadripper\n(Zen 2 (Matisse))                         unknown
# 1975  Ryzen Threadripper\n(Zen 2 (Matisse))                         unknown
#
#      Memory Support:  # of Cores:  # of Threads:  SMP # CPUs:  \
# 0            unknown            1              1            1
# 1            unknown            1              1            1
# 2            unknown            1              1            1
# 3         DDR1, DDR2            1              1            1
# 4         DDR1, DDR2            1              1            1
# ...              ...          ...            ...          ...
# 1971            DDR4           12             24            1
# 1972            DDR4           16             32            1
# 1973            DDR4           24             48            1
# 1974            DDR4           32             64            1
# 1975            DDR4           48             96            1
#
#      Integrated Graphics:       Cache L1:        Cache L2: Cache L3:
# 0                     N/A              8K             256K       NaN
# 1                     N/A              8K             256K       NaN
# 2                     N/A              8K             256K       NaN
# 3                     N/A              8K             256K       NaN
# 4                     N/A              8K             256K       NaN
# ...                   ...             ...              ...       ...
# 1971                  N/A  96K (per core)  512K (per core)      64MB
# 1972                  N/A  96K (per core)  512K (per core)      64MB
# 1973                  N/A  96K (per core)  512K (per core)     128MB
# 1974                  N/A  96K (per core)  512K (per core)     128MB
# 1975                  N/A  96K (per core)  512K (per core)     128MB
#
# [1025 rows x 31 columns]

# %%
df = cpu_date_parser(new_list)
df = df.set_index('Released:')
df.columns = ["name",'brand','generation',"codename",'frequency','num_cores']

# %%
df['frequency'] = df['frequency'].apply(prefixed_number_to_int)
df['generation'] = df['generation'].apply(generation_scrubber)

# %%
len(df)
# Out:
# 1025

# %%
df = df.merge(code_flops_df[['Code name',"dp_flops", 'sp_flops']], left_on='codename', right_on='Code name')

# %%
df['gflops'] = df['frequency']*df['num_cores']*df['sp_flops']

# %%
df.to_pickle("../../data/preprocessed_data/final_cpu_df.pkl")

# %%
p = pd.read_pickle("../../data/preprocessed_data/final_cpu_df.pkl")

# %%
p
# Out:
#                           name  brand          generation    codename  \
# 0                Pentium 4 1.4  Intel           Pentium 4  Willamette
# 1                Pentium 4 1.5  Intel           Pentium 4  Willamette
# 2                Pentium 4 1.3  Intel           Pentium 4  Willamette
# 3                Pentium 4 1.4  Intel           Pentium 4  Willamette
# 4                Pentium 4 1.5  Intel           Pentium 4  Willamette
# ...                        ...    ...                 ...         ...
# 1020             Ryzen 9 3900X    AMD             Ryzen 9     Matisse
# 1021             Ryzen 9 3950X    AMD             Ryzen 9     Matisse
# 1022  Ryzen Threadripper 3960X    AMD  Ryzen Threadripper     Matisse
# 1023  Ryzen Threadripper 3970X    AMD  Ryzen Threadripper     Matisse
# 1024  Ryzen Threadripper 3980X    AMD  Ryzen Threadripper     Matisse
#
#       frequency  num_cores   Code name  dp_flops  sp_flops  gflops
# 0           1.4          1  Willamette       2.0       4.0     5.6
# 1           1.5          1  Willamette       2.0       4.0     6.0
# 2           1.3          1  Willamette       2.0       4.0     5.2
# 3           1.4          1  Willamette       2.0       4.0     5.6
# 4           1.5          1  Willamette       2.0       4.0     6.0
# ...         ...        ...         ...       ...       ...     ...
# 1020        3.8         12     Matisse       8.0      16.0   729.6
# 1021        3.5         16     Matisse       8.0      16.0   896.0
# 1022        3.8         24     Matisse       8.0      16.0  1459.2
# 1023        3.7         32     Matisse       8.0      16.0  1894.4
# 1024        3.5         48     Matisse       8.0      16.0  2688.0
#
# [1025 rows x 10 columns]
